# %%
import requests

# %%
url = 'https://timesofindia.indiatimes.com/technology/tech-news/us-may-ban-follow-indias-ban-on-another-chinese-technology-giant/articleshow/116223973.cms'

# %%
r = requests.get(url)

# %%
r
# Out:
# <Response [200]>

# %%
import requests
def fetchandsave(url,path):
    r = requests.get(url)
    with open(path, 'w') as f:
        f.write(r.text)

# %%
fetchandsave(url, 'data/article.html')

# %%
proxy = "http://5990352685421c3bc23ace4cb8d626594e4f826e:@api.zenrows.com:8001"
proxies = {"http": proxy, "https": proxy}

# %%
proxies
# Out:
# {'http': 'http://5990352685421c3bc23ace4cb8d626594e4f826e:@api.zenrows.com:8001',
#  'https': 'http://5990352685421c3bc23ace4cb8d626594e4f826e:@api.zenrows.com:8001'}

# %%
response = requests.get(url, proxies=proxies, verify=False)
print(response.text)
# Out:
# d:\a27_YEARS_OLD\data_collection\venv\Lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.zenrows.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# ...

# %%
import requests
from bs4 import BeautifulSoup

with open("sample.html") as f:
    html_doc = f.read()

soup = BeautifulSoup(html_doc, 'html.parser')
# print(soup.prettify())
# print(soup.title.string, type(soup.title.string))
# print(soup.div)
# print(soup.find_all('div')[0]) # returns a list  class_='article_content'
# print(type(soup.find_all('div')[0]))

# %%
for link in soup.find_all('a'):
    print(link.get('href'))
    print(link.get_text())
# Out:
# http://example.com/elsie
# Elsie
# http://example.com/lacie
# Lacie
# http://example.com/tillie
# Tillie
# http://example.com/elsie
#
#         # Elsie #
#
# http://example.com/lacie
#
#         # Lacie #
#
# http://example.com/tillie
#
#         # Tillie #

# %%
s = soup.find(id='link3')
print(s.href)
print(s.get('href'))
# Out:
# None
# http://example.com/tillie

# %%
print(soup.select('div.italic'))
print(soup.select('div#italic'))
print(soup.span.get("class"))
# Out:
# []
# []
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[27], line 3
#       1 print(soup.select('div.italic'))
#       2 print(soup.select('div#italic'))
# ----> 3 print(soup.span.get("class"))
#
# AttributeError: 'NoneType' object has no attribute 'get'

# %%
print(soup.find(class_="italic"))
# Out:
# None

# %%
for child in soup.find(class_='story').children:
    print(child)
# Out:
#       Once upon a time there were three little sisters; and their names were
#
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>
# ,
#
# <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>
#  and
#
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>
# ;
#       and they lived at the bottom of a well.

# %%
for parent in soup.find(class_='story').children:
    print(parent)
# Out:
#       Once upon a time there were three little sisters; and their names were
#
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>
# ,
#
# <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>
#  and
#
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>
# ;
#       and they lived at the bottom of a well.

# %%
i = 0
for parent in soup.find(class_='story').children:
    i += 1
    print(parent)
    if i == 3:
        break
# Out:
#       Once upon a time there were three little sisters; and their names were
#
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>
# ,

# %%
cont = soup.find(class_='story')
cont
# Out:
# <p class="story">
#       Once upon a time there were three little sisters; and their names were
#       <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
#       <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a> and
#       <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>;
#       and they lived at the bottom of a well.
#     </p>

# %%
cont.name = 'span'

# %%
print(cont)
# Out:
# <span class="story">
#       Once upon a time there were three little sisters; and their names were
#       <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
#       <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a> and
#       <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>;
#       and they lived at the bottom of a well.
#     </span>

# %%
cont["class"] = "myclass class2"

# %%
cont.string = "I am a string"

# %%
print(cont)
# Out:
# <span class="myclass class2">I am a string</span>

# %%
ulTag = soup.new_tag('ul')
liTag = soup.new_tag('li')
liTag.string = 'Home'
ulTag.append(liTag)

# %%
liTag = soup.new_tag('li')
liTag.string = 'New Item'
ulTag.append(liTag)

# %%
soup.html.body.insert(0, ulTag)
with open("modified.html", "w") as f:
    f.write(str(soup))

# %%
cont = soup.find(class_='story')
print(cont.has_attr("contenteditable"))
# Out:
# False

# %%
def has_class_but_not_id(tag):
    return tag.has_attr('class') and not tag.has_attr('id')

# %%
results = soup.find_all(has_class_but_not_id)
print(results)
# Out:
# [<p class="title"><b>The Dormouse's story</b></p>, <span class="myclass class2">I am a string</span>, <p class="story">...</p>, <p class="title"># <b> # The Dormouse's story # </b> #</p>, <p class="story">
#       # Once upon a time there were three little sisters; and their names were #
#       <a class="sister" href="http://example.com/elsie" id="link1">
#         # Elsie #
#       </a>
#       # , #
#       <a class="sister" href="http://example.com/lacie" id="link2">
#         # Lacie #
#       </a>
#       # and #
#       <a class="sister" href="http://example.com/tillie" id="link3">
#         # Tillie #
#       </a>
#       # ; and they lived at the bottom of a well. #
#     </p>, <p class="story"># ... #</p>]

# %%
def has_content(tag):
    return tag.has_attr('content')

# %%
results = soup.find_all(has_class_but_not_id)
for result in results:
    print(result, '\n\n')
# Out:
# <p class="title"><b>The Dormouse's story</b></p>
#
#
# <span class="myclass class2">I am a string</span>
#
#
# <p class="story">...</p>
#
#
# <p class="title"># <b> # The Dormouse's story # </b> #</p>
#
#
# <p class="story">
#       # Once upon a time there were three little sisters; and their names were #
#       <a class="sister" href="http://example.com/elsie" id="link1">
#         # Elsie #
#       </a>
#       # , #
#       <a class="sister" href="http://example.com/lacie" id="link2">
#         # Lacie #
#       </a>
#       # and #
#       <a class="sister" href="http://example.com/tillie" id="link3">
#         # Tillie #
#       </a>
#       # ; and they lived at the bottom of a well. #
#     </p>
#
#
# <p class="story"># ... #</p>
